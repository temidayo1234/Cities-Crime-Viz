# %%
# Dependencies
import numpy as np 
import pandas as pd
pd.set_option('display.max_rows', 30000)
import warnings
warnings.filterwarnings('ignore')
from sqlalchemy import create_engine

# %% [markdown]
# ## Lowest Crime Vs Education

# %%
#lowest crime file
dmv_crime = "2019_NineStates_ViolentCrime.csv"
dmv_crime_df = pd.read_csv(dmv_crime)
dmv_crime_df["State"]=dmv_crime_df['State'].str.title()

dmv_crime_df.to_csv("2019_NineStates_ViolentCrime.csv", index=False)

# %%
education = "education.csv"
education_df=pd.read_csv(education)
#education_df["City"] = education_df['City'].replace("Wrangell city and borough","Wrangell")
#merge the two files
merge_df=pd.merge(left=dmv_crime_df, right=education_df, on=['State','City'], how='left')
merge_df=merge_df.dropna().reset_index(drop=True)
merge_df=merge_df.astype({'Total': 'float'})
#create new columns for percentage calculation
merge_df['none']=''
merge_df['high_school']=''
merge_df['associate']=''
merge_df['bachelor']=''
merge_df['graduate']=''
#create list to hold the percent calculation from for loop
p_none=[]
p_HS=[]
p_AS=[]
p_BA=[]
p_GR=[]
#Percentage of each category
for index,row in merge_df.iterrows():
    if (row['None'] or row['High School'] or row['Associates'] or row['Bachelors'] or row['Graduate']) == 0:
        p_none.append(0)
        p_HS.append(0)
        p_AS.append(0)
        p_BA.append(0)
        p_GR.append(0)
    else:
        pNone = (row['None']/row['Total'])*100
        p_none.append(round(pNone,2))
        pHS = (row['High School']/row['Total'])*100
        p_HS.append(round(pHS,2))
        pAS = (row['Associates']/row['Total'])*100
        p_AS.append(round(pAS,2))
        pBA = (row['Bachelors']/row['Total'])*100
        p_BA.append(round(pBA,2))
        pGR = (row['Graduate']/row['Total'])*100
        p_GR.append(round(pGR,2))
#Insert percent into dataframe
merge_df['none']=p_none
merge_df['high_school']=p_HS
merge_df['associate']=p_AS
merge_df['bachelor']=p_BA
merge_df['graduate']=p_GR

merge_df1=merge_df.loc[:,['State','City','none','high_school','associate','bachelor','graduate']]
merge_df1['Location']= merge_df1['City']+', ' + merge_df1['State']
merge_df1=merge_df1.loc[:,['Location','none','high_school','associate','bachelor','graduate']]
#merge_df1= merge_df1.T
#merge_df1.to_csv("educationcrime2.csv", index=True)
merge_df1
# Out:
#                                   Location    none  high_school  associate  \
# 0                  Pismo Beach, California    3.30        17.17      31.73
# 1                    Patterson, California   25.00        36.51      28.70
# 2                       Perris, California   33.79        30.87      26.85
# 3                     Piedmont, California    0.80         3.05      13.21
# 4                  Pico Rivera, California   28.74        32.01      26.57
# 5                       Pinole, California   11.53        17.39      39.38
# 6                    Pittsburg, California   19.73        25.40      34.58
# 7                     Pasadena, California   11.92        14.30      22.56
# 8                     Petaluma, California   10.59        16.65      33.00
# 9                      Parlier, California   52.97        25.53      17.35
# 10                    Pacifica, California    5.35        16.77      33.29
# ...

# %% [markdown]
# ## Lowest Crime Vs Race

# %%
#race file
race ="race.csv"
race_df=pd.read_csv(race)
#race_df["City"] = race_df['City'].replace("Wrangell city and borough","Wrangell")
#merge the two files
merge_df=pd.merge(left=dmv_crime_df, right=race_df, on=['State','City'], how='left')
merge_df=merge_df.dropna().reset_index(drop=True)
#create new columns for percentage calculation
merge_df['Blacks']=''
merge_df['AmericanIndian_AlaskanNatives']=''
merge_df['Asians']=''
merge_df['NativeHawaiian_PacificIslanders']=''
merge_df['Whites']=''
merge_df['Others']=''
merge_df['Two_or_Mores']=''
merge_df['Hispanic_Latinos']=''
#create list to hold the percent calculation from for loop
p_other=[]
p_HP=[]
p_AA=[]
p_W=[]
p_PI=[]
p_A=[]
p_TM=[]
p_AN=[]
#Percentage of each category
for index,row in merge_df.iterrows():
    if (row['Black'] or row['American Indian/Alaskan Native'] or row['Asian'] or row['Native Hawaiian / Pacific Islander'] or row['White'] or row['Two or More'] or row['Hispanic/Latino'] or row['Other']) == 0:
        p_AA.append(0)
        p_other.append(0)
        p_HP.append(0)
        p_W.append(0)
        p_A.append(0)
        p_TM.append(0)
        p_AN.append(0)
        p_PI.append(0)
    else:
        pOther = (row['Other']/row['Total'])*100
        p_other.append(round(pOther,2))
        pHP = (row['Hispanic/Latino']/row['Total'])*100
        p_HP.append(round(pHP,2))
        pAA = (row['Black']/row['Total'])*100
        p_AA.append(round(pAA,2))
        pW = (row['White']/row['Total'])*100
        p_W.append(round(pW,2))
        pPI = (row['Native Hawaiian / Pacific Islander']/row['Total'])*100
        p_PI.append(round(pPI,2))
        pA = (row['Asian']/row['Total'])*100
        p_A.append(round(pA,2))
        pTM = (row['Two or More']/row['Total'])*100
        p_TM.append(round(pTM,2))
        pAN = (row['American Indian/Alaskan Native']/row['Total'])*100
        p_AN.append(round(pAN,2))
#Insert percent into dataframe
merge_df['Blacks']=p_AA
merge_df['AmericanIndian_AlaskanNatives']=p_AN
merge_df['Asians']=p_A
merge_df['NativeHawaiian_PacificIslanders']=p_PI
merge_df['Whites']=p_W
merge_df['Others']=p_other
merge_df['Two_or_Mores']=p_TM
merge_df['Hispanic_Latinos']=p_HP

merge_df2=merge_df.loc[:,['State','City','Blacks','Asians','NativeHawaiian_PacificIslanders','Whites',
                          'Hispanic_Latinos','AmericanIndian_AlaskanNatives','Two_or_Mores','Others']]
merge_df2['Location']= merge_df2['City']+', ' + merge_df2['State']
merge_df2=merge_df2.loc[:,['Location','Blacks','Asians','NativeHawaiian_PacificIslanders','Whites',
                          'Hispanic_Latinos','AmericanIndian_AlaskanNatives','Two_or_Mores','Others']]
#merge_df2 = merge_df2.T
merge_df2.to_csv("racecrime.csv", index=True)

# %% [markdown]
# ## Lowest Crime Vs Marital Status

# %%
#Marital Status
marital_status ="marital_status.csv"
ms_df=pd.read_csv(marital_status)
#ms_df["City"] = ms_df['City'].replace("Wrangell city and borough","Wrangell")
#merge the two files
merge_df=pd.merge(left=dmv_crime_df, right=ms_df, on=['State','City'], how='left')
merge_df=merge_df.dropna().reset_index(drop=True)
#create new columns for percentage calculation
merge_df['Never_Marrieds']=''
merge_df['Marrieds']=''
merge_df['Divorceds']=''
merge_df['Separateds']=''
merge_df['Widoweds']=''
#create list to hold the percent calculation from for loop
p_NM=[]
p_M=[]
p_D=[]
p_S=[]
p_W=[]
#Percentage of each category
for index,row in merge_df.iterrows():
    if (row['Never Married'] or row['Married'] or row['Divorced'] or row['Separated'] or row['Widowed']) == 0:
        p_NM.append(0)
        p_M.append(0)
        p_D.append(0)
        p_S.append(0)
        p_W.append(0)
    else:
        pNM = (row['Never Married']/row['Total'])*100
        p_NM.append(round(pNM,2))
        pM = (row['Married']/row['Total'])*100
        p_M.append(round(pM,2))
        pD = (row['Divorced']/row['Total'])*100
        p_D.append(round(pD,2))
        pS = (row['Separated']/row['Total'])*100
        p_S.append(round(pS,2))
        pW = (row['Widowed']/row['Total'])*100
        p_W.append(round(pW,2))
#Insert percent into dataframe
merge_df['Never_Marrieds']=p_NM
merge_df['Marrieds']=p_M
merge_df['Divorceds']=p_D
merge_df['Separateds']=p_S
merge_df['Widoweds']=p_W

merge_df3=merge_df.loc[:,['State', 'City','Never_Marrieds','Marrieds','Divorceds',
                          'Separateds','Widoweds']]
merge_df3['Location']= merge_df3['City']+', ' + merge_df3['State']
merge_df3=merge_df3.loc[:,['Location','Never_Marrieds','Marrieds','Divorceds',
                          'Separateds','Widoweds']]
#merge_df3 = merge_df3.T
merge_df3.to_csv("maritalstatuscrime.csv", index=True)
#merge_df3

# %% [markdown]
# ## Lowest Crime Vs Income

# %%
#Income
income="income.csv"
income_df=pd.read_csv(income)
income_df["City"] = income_df['City'].replace("Wrangell city and borough","Wrangell")
#merge the two files
merge_df=pd.merge(left=lowest_crime_df, right=income_df, on=['State','City'], how='left')
merge_df=merge_df.dropna().reset_index(drop=True)
merge_df['Median_Income'] = merge_df['Median Income'].copy()
merge_df4=merge_df.loc[:,['State','City', 'Median_Income']]
merge_df4['Location']= merge_df4['City']+', ' + merge_df4['State']
merge_df4=merge_df4.loc[:,['Location', 'Median_Income']]
#merge_df4 = merge_df4.T
#merge_df4.to_csv("incomecrime2.csv", index=True)
#state_avg=merge_df.loc[:,['State','City', 'Median_Income']]
#state_avg = state_avg.groupby('State')
#state_avg = round(state_avg['Median_Income'].mean(),2)
#state_avg.to_csv("income_state_average.csv", index=False)

# %% [markdown]
# ## Lowest Crime Vs Unemployment

# %%
#Unemployment Count
unemployment="unemployment.csv"
ue_df=pd.read_csv(unemployment)
ue_df["City"] = ue_df['City'].replace("Wrangell city and borough","Wrangell")
#merge the two files
merge_df=pd.merge(left=lowest_crime_df, right=ue_df, on=['State','City'], how='left')
merge_df=merge_df.dropna().reset_index(drop=True)

#create new columns for percentage calculation
merge_df['Unemployment']=''
#create list to hold the percent calculation from for loop
p_UE=[]
#Percentage of each category
for index,row in merge_df.iterrows():
    pUE = (row['Unemployment Count']/row['Population'])*100
    p_UE.append(round(pUE,2))
#Insert percent into dataframe
merge_df['Unemployment']=p_UE
merge_df6=merge_df.loc[:,['State','City','Unemployment']]
merge_df6['Location']= merge_df6['City']+', ' + merge_df6['State']
merge_df6=merge_df6.loc[:,['Location','Unemployment']]
#merge_df6 = merge_df6.T
#merge_df6.to_csv("unemploymentcrime2.csv", index=True)
#unemploy_state_avg=merge_df.loc[:,['State','City', 'Unemployment']]
#unemploy_state_avg = unemploy_state_avg.groupby('State')
#unemploy_state_avg = round(unemploy_state_avg['Unemployment'].mean(),2)
#unemploy_state_avg.to_csv("unemployment_state_average.csv", index=True)

# %% [markdown]
# ## Lowest Crime Vs Population

# %%
#Population
education ="education.csv"
education_df=pd.read_csv(education)
education_df["City"] = education_df['City'].replace("Wrangell city and borough","Wrangell")
#merge the two files
merge_df=pd.merge(left=lowest_crime_df, right=education_df, on=['State','City'], how='left')
merge_df=merge_df.dropna().reset_index(drop=True)
merge_df5=merge_df.loc[:,['State','City', 'Population']]
merge_df5['Location']= merge_df5['City']+', ' + merge_df5['State']
merge_df5=merge_df5.loc[:,['Location','Population']]
merge_df5.to_csv("totalpopulation.csv", index=False)
merge_df5
# Out:
#                         Location  Population
# 0             La Plata, Maryland      8994.0
# 1        Mount Rainier, Maryland      8329.0
# 2               Laurel, Maryland     25849.0
# 3          Westminster, Maryland     18646.0
# 4           Manchester, Maryland      4814.0
# 5       Landover Hills, Maryland      1903.0
# 6            Hampstead, Maryland      6351.0
# 7              Hurlock, Maryland      1958.0
# 8       Havre de Grace, Maryland     13445.0
# 9           Hagerstown, Maryland     40210.0
# 10      New Carrollton, Maryland     12542.0
# 11          Greensboro, Maryland      2020.0
# 12         Hyattsville, Maryland     18225.0
# 13          North East, Maryland      3700.0
# 14           Taneytown, Maryland      6740.0
# 15          Perryville, Maryland      4427.0
# 16       Pocomoke City, Maryland      4162.0
# 17       Princess Anne, Maryland      3325.0
# 18             Ridgely, Maryland      1379.0
# 19      Riverdale Park, Maryland      7169.0
# ...

# %%
merge_df7=pd.merge(left=merge_df6, right=merge_df4, on=['Location'], how='left')
merge_df7
# Out:
#                         Location  Unemployment  Median_Income
# 0             La Plata, Maryland          1.99            NaN
# 1        Mount Rainier, Maryland          7.20        29065.0
# 2               Laurel, Maryland          5.14        40609.0
# 3          Westminster, Maryland          3.65        28861.0
# 4           Manchester, Maryland          1.97            NaN
# 5       Landover Hills, Maryland          7.76            NaN
# 6            Hampstead, Maryland          2.75            NaN
# 7              Hurlock, Maryland         13.06        21526.0
# 8       Havre de Grace, Maryland          6.44        31951.0
# 9           Hagerstown, Maryland          7.97        21987.0
# 10      New Carrollton, Maryland          9.60        31556.0
# 11          Greensboro, Maryland          9.93        24944.0
# 12         Hyattsville, Maryland          5.17        31316.0
# 13          North East, Maryland          5.18            NaN
# ...

# %%
engine = create_engine("postgres://bzrdcgiroyqhig:be78f064792875b8b408ad25e12e2698a2f9ee5d889c37d70f198def06b58fed@ec2-3-220-23-212.compute-1.amazonaws.com:5432/d8vi2ghbfhg1ss")

# %%
engine.table_names()
# Out:
# []

# %%
merge_df2.to_sql(name='crime_race', con=engine, if_exists='replace', index=False)

# %%
merge_df1.to_sql(name='crime_education', con=engine, if_exists='replace', index=False)

# %%
merge_df4.to_sql(name='crime_income', con=engine, if_exists='replace', index=False)

# %%
merge_df6.to_sql(name='crime_unemployment', con=engine, if_exists='replace', index=False)

# %%
merge_df5.to_sql(name='crime_population', con=engine, if_exists='replace', index=False)

# %%
merge_df3.to_sql(name='crime_maritalstatus', con=engine, if_exists='replace', index=False)

# %%
merge_df7.to_sql(name='crime_incomeunemploy', con=engine, if_exists='replace', index=False)

# %%
dmv_crime_df.to_sql(name='crime_location', con=engine, if_exists='replace', index=False)
